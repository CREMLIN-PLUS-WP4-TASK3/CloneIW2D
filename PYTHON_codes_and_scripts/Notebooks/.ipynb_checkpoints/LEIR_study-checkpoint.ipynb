# %% [markdown]
# # LEIR optics

# %%
# %pylab notebook 
import pyoptics as opt
OpticsDir='/afs/cern.ch/user/n/nbiancac/scratch0/HDTLattice/LEIR/out/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tfs=opt.optics.open(OpticsDir+'optics_basic_LEIR2012.out')
plot(tfs.s,tfs.betx,'-b')
plot(tfs.s,tfs.bety,'-r')
plot(tfs.s,tfs.dx,'-g')
tfs.show('UQF11','betx bety s dx')
# tfs.plotbeta()
# Out:
# <img src="data:image/png;base64,...">
# names            betx         bety         s            dx
# UQF11               6.728       15.512      361.340e-03  -50.366
